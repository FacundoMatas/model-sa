# %%
import pandas as pd
import re
import string
from nltk.corpus import stopwords
import numpy as np
from nltk.metrics import *
from sklearn import metrics
from os import scandir, getcwd
import json

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Definimos donde esta el diccionario y los tweets, ademas de que experimento realizar. La variable "clasificacion" indica si se usa clasificación binaria o ternaria

# %%
diccionario = "SEL.xlsx"
tweets = 'tweets_preprocessed.xlsx'


path = files_path=getcwd()
# file = "binario_experimento6"
# directory = '\\binario\\'
file_1 = "SEL_1"
file_2 = "SEL_2"
# directory = '\\BINARIO\\'
directory = '\\TERNARIO\\'


filename1 = path+directory+file_1
filename2 = path+directory+file_2
nombre = 'SEL'

clasificacion = 3

# %%
df = pd.read_excel(diccionario)

# %%
dict_part = df

# %% [markdown]
# #### Se adaptan las categorias del diccionario a la polaridad positiva y negativa

# %%
def polaridad(row):
    pos=['Alegría']
    neg=['Enojo', 'Miedo','Repulsión','Tristeza']
    if row['Categoría'] in neg:
        row['Categoría'] = -1       
    else:
        row['Categoría'] = 1    
    return row['Categoría']

# %%
dict_label=dict_part

# %%
dict_label['Categoría'] = dict_label.apply(polaridad, axis=1)
dict_label
# Out:
#          #         Palabra    PFA  Categoría
# 0        1      abundancia  0.830          1
# 1        2        acabalar  0.396          1
# 2        3         acallar  0.198          1
# 3        4          acatar  0.198          1
# 4        5          acción  0.397          1
# 5        6       aceptable  0.594          1
# 6        7      aceptación  0.696          1
# 7        8         acicate  0.429          1
# 8        9      aclamación  0.799          1
# 9       10         aclamar  0.799          1
# 10      11        acogedor  0.830          1
# 11      12          acoger  0.729          1
# 12      13  acomodadamente  0.729          1
# 13      14         acuciar  0.264          1
# 14      15        acucioso  0.232          1
# 15      16         adecuar  0.331          1
# 16      17          adicto  0.429          1
# 17      18       admirable  0.764          1
# 18      19  admirablemente  0.765          1
# 19      20      admiración  0.765          1
# 20      21         admirar  0.731          1
# 21      22         admitir  0.530          1
# 22      23        adorable  0.898          1
# 23      24   adorablemente  0.865          1
# 24      25       adoración  0.765          1
# 25      26        adorador  0.664          1
# 26      27          adorar  0.764          1
# 27      28          afable  0.696          1
# 28      29            afán  0.764          1
# 29      30        afectivo  0.864          1
# ...    ...             ...    ...        ...
# 2006  2014          privar  0.496         -1
# 2007  2015       quebranto  0.628         -1
# 2008  2016         reducir  0.099         -1
# 2009  2017   remordimiento  0.595         -1
# 2010  2018           ruina  0.430         -1
# 2011  2019           serio  0.132         -1
# 2012  2020         soledad  0.763         -1
# 2013  2021       solitario  0.830         -1
# 2014  2022        sollozar  0.798         -1
# 2015  2023            solo  0.729         -1
# 2016  2024         sombrío  0.397         -1
# 2017  2025     sufrimiento  0.898         -1
# 2018  2026          sufrir  0.898         -1
# 2019  2027     sumisamente  0.430         -1
# 2020  2028    taciturnidad  0.431         -1
# 2021  2029       taciturno  0.464         -1
# 2022  2030           temor  0.198         -1
# 2023  2031  tenebrosamente  0.198         -1
# 2024  2032    tenebrosidad  0.132         -1
# 2025  2033       tenebroso  0.132         -1
# 2026  2034         tétrico  0.199         -1
# 2027  2035        tormento  0.530         -1
# 2028  2036          triste  0.966         -1
# 2029  2037     tristemente  0.966         -1
# 2030  2038        tristeza  0.966         -1
# 2031  2039          trizas  0.464         -1
# 2032  2040        vejación  0.297         -1
# 2033  2041           vejar  0.396         -1
# 2034  2042      vergonzoso  0.231         -1
# 2035  2043    zangarriana   0.530         -1
#
# [2036 rows x 4 columns]

# %%
dict_label = dict_label.drop_duplicates(['Palabra'], keep='first')

# %% [markdown]
# #### Se lee el conjunto de tweets

# %%
df = pd.read_excel(tweets)

# %%
df_label = df[df.sentiment < clasificacion]

# %%
df_label = df_label.drop_duplicates(['text'], keep='first')

# %%
df_label = df_label.dropna()

# %%
df_label = df_label.replace(0, -1)

# %% [markdown]
# #### Como se eliminaron los acentos del conjunto de tweets, tambien se eliminan de las palabras del diccionario

# %%
def preprocesamiento_dict(row):
    a,b = 'áéíóúü','aeiouu'
    trans = str.maketrans(a,b)
    replaced_links = row["Palabra"].translate(trans)  
    
    return replaced_links

# %% [markdown]
# #### Dividimos en conjuntos de prueba y entrenamiento

# %%
train=df_label.sample(frac=0.8,random_state=200)
test=df_label.drop(train.index)

train = train[train.sentiment < clasificacion]

df_label = train
df_clean = train

# %% [markdown]
# #### Aplicamos el preprocesamiento al diccionario

# %%
dict_label = dict_label.drop_duplicates(subset=['Palabra'])
dict_label["Palabra"] = dict_label.apply(preprocesamiento_dict, axis=1)
dict_label
# Out:
#          #         Palabra    PFA  Categoría
# 0        1      abundancia  0.830          1
# 1        2        acabalar  0.396          1
# 2        3         acallar  0.198          1
# 3        4          acatar  0.198          1
# 4        5          accion  0.397          1
# 5        6       aceptable  0.594          1
# 6        7      aceptacion  0.696          1
# 7        8         acicate  0.429          1
# 8        9      aclamacion  0.799          1
# 9       10         aclamar  0.799          1
# 10      11        acogedor  0.830          1
# 11      12          acoger  0.729          1
# 12      13  acomodadamente  0.729          1
# 13      14         acuciar  0.264          1
# 14      15        acucioso  0.232          1
# 15      16         adecuar  0.331          1
# 16      17          adicto  0.429          1
# 17      18       admirable  0.764          1
# 18      19  admirablemente  0.765          1
# 19      20      admiracion  0.765          1
# 20      21         admirar  0.731          1
# 21      22         admitir  0.530          1
# 22      23        adorable  0.898          1
# 23      24   adorablemente  0.865          1
# 24      25       adoracion  0.765          1
# 25      26        adorador  0.664          1
# 26      27          adorar  0.764          1
# 27      28          afable  0.696          1
# 28      29            afan  0.764          1
# 29      30        afectivo  0.864          1
# ...    ...             ...    ...        ...
# 2000  2008         pobrete  0.363         -1
# 2001  2009         pobreto  0.363         -1
# 2002  2010         pobreza  0.396         -1
# 2004  2012       preocupar  0.462         -1
# 2005  2013       presionar  0.264         -1
# 2006  2014          privar  0.496         -1
# 2007  2015       quebranto  0.628         -1
# 2008  2016         reducir  0.099         -1
# 2009  2017   remordimiento  0.595         -1
# 2010  2018           ruina  0.430         -1
# 2011  2019           serio  0.132         -1
# 2012  2020         soledad  0.763         -1
# 2013  2021       solitario  0.830         -1
# 2014  2022        sollozar  0.798         -1
# 2015  2023            solo  0.729         -1
# 2016  2024         sombrio  0.397         -1
# 2017  2025     sufrimiento  0.898         -1
# 2018  2026          sufrir  0.898         -1
# 2019  2027     sumisamente  0.430         -1
# 2020  2028    taciturnidad  0.431         -1
# 2021  2029       taciturno  0.464         -1
# 2023  2031  tenebrosamente  0.198         -1
# 2024  2032    tenebrosidad  0.132         -1
# 2025  2033       tenebroso  0.132         -1
# 2026  2034         tetrico  0.199         -1
# 2028  2036          triste  0.966         -1
# 2029  2037     tristemente  0.966         -1
# 2030  2038        tristeza  0.966         -1
# 2031  2039          trizas  0.464         -1
# 2035  2043    zangarriana   0.530         -1
#
# [1909 rows x 4 columns]

# %%
dict_label.reset_index()

# %% [markdown]
# #### Esta función calcula la polaridad promedio de una palabra que no se encuentra en el diccionario, a partir de las polaridades de los tweets donde aparece

# %%
def polaridadPromedio(palabra):
    tweetsQueTienenPalabra = df_clean[df_clean['text'].str.contains(palabra)]
    avg = tweetsQueTienenPalabra["sentiment"].mean()
    return avg

# %%
df_aux = df_clean

for id, tweet in df_aux.iterrows():
    filtered_words = [word for word in tweet.text.split() if word not in stopwords.words('spanish')]
    for word in filtered_words:
        if dict_label.loc[dict_label['Palabra'].isin([word])]['Palabra'].any():
            a=1
        else:        
            avg = polaridadPromedio(str(word))
            df2 = pd.DataFrame([[word,1,avg]], columns=['Palabra','PFA','Categoría'])
            dict_label = dict_label.append(df2)

# %% [markdown]
# #### Esta función determina la polaridad de un tweet en funcion del diccionario

# %%
def analisis_sentimiento(text):
    tienePalabra = False
    valor = 999999
    filtered_words = [word for word in text.split() if word not in stopwords.words('spanish')]
    for word in filtered_words:
        if dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'].any(): 
            if not tienePalabra:
                tienePalabra = True
                valor = 0
            try:                
                valor = valor + float(dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'])
            except Exception as e: 
                print(e)
                print(dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'])               
    
    return valor

# %% [markdown]
# #### Se calcula la polaridad del conjunto de tweets de test

# %%
correcto = 0
max = 0
min = 0
ref = []
testVal= []

if(clasificacion == 2):
    #BINARIO
    for id, tweet in test.iterrows(): 
        sentimiento = analisis_sentimiento(str(tweet.text))
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento  
            ref.append(1 if int(tweet.sentiment) == 1 else -1)      
            if(sentimiento <= -1): 
                testVal.append(-1)
            else:
                testVal.append(1)
        
else:
    #TERNARIO
    for id, tweet in test.iterrows():    
        sentimiento = analisis_sentimiento(str(tweet.text))
        if (int(tweet.sentiment) == 0):
            valor_tweet = -1
        else: 
            valor_tweet = int(tweet.sentiment)
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento
            ref.append(valor_tweet)  
            if sentimiento > 3 and sentimiento < 7:
                testVal.append(2)
            elif(sentimiento <= 4): 
                testVal.append(-1)
            else:
                testVal.append(1)

# %% [markdown]
# #### Guardamos los resultados de la clasificación.

# %%
file1 = open(filename1 + '.txt',"w") 

accuracyDict = {}
  
# \n is placed to indicate EOL (End of Line) 
file1.write("Resultados "+ filename1 + ' \n\n') 

writer = pd.ExcelWriter(path+directory+'clasification_report_'+file_1+'.xlsx', engine='xlsxwriter')
writerCM = pd.ExcelWriter(path+directory+'confusion_matrix_'+file_1+'.xlsx', engine='xlsxwriter')

#     print("***** METRICAS CLASIFICADOR "+nombre+" *****")
file1.write("***** METRICAS DICCIONARIO: SEL *****\n\n") 
#     print("Exactitud (accuracy) " +  str(accuracy(ref, test)*100))
file1.write("Exactitud (accuracy) " +  str(accuracy(ref, testVal)*100)+"\n") 
reference_set = set(ref)
test_set = set(testVal)
#     print("Precision " +str(precision(reference_set, test_set)))
file1.write("Precision " +str(precision(reference_set, test_set))+"\n")
#     print("Recall " +str(recall(reference_set, test_set)))
file1.write("Recall " +str(recall(reference_set, test_set))+"\n")
#     print("F measure " + str(f_measure(reference_set, test_set)))
file1.write("F measure " + str(f_measure(reference_set, test_set))+"\n\n")
file1.write("Matriz de confusión \n")
#     print(ConfusionMatrix(ref, test))   
file1.write(str(ConfusionMatrix(ref, testVal)))
file1.write('\n')
file1.write("Reporte de clasificación\n")
#     print(metrics.classification_report(ref,test,digits=3))
file1.write(metrics.classification_report(ref,testVal,digits=3)+'\n')
    
    
    
data = {'y_Predicted': testVal,
    'y_Actual':   ref
    }

df_cm = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
confusion_matrix = pd.crosstab(df_cm['y_Actual'], df_cm['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

confusion_matrix.to_excel(writerCM,sheet_name=nombre) 

report = metrics.classification_report(ref, testVal, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_excel(writer,sheet_name=nombre)


file1.write("****************************************\n\n\n\n")

accuracyDict[nombre] = str(accuracy(ref, testVal)*100)

df_ac = pd.DataFrame([accuracyDict])   
df_ac = df_ac.T
df_ac.to_excel(path+directory+'accuracy_'+file_1+'.xlsx')

file1.close() #to change file access modes 
writer.save()

# %% [markdown]
# # Stemmer

# %% [markdown]
# #### Aplicamos stemming a la clasificación con diccionarios.

# %%
dict_label_stem = dict_label

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')

# %% [markdown]
# #### Función que aplica el algoritmo de stemming a un texto.

# %%
def lematizacion(row):
    result = stemmer.stem(row['Palabra'])
    return result

# %%
dict_label= dict_label_stem
dict_label['Palabra'] = dict_label.apply(lematizacion, axis=1)
dict_label
# Out:
#        #  Categoría    PFA         Palabra
# 0    1.0   1.000000  0.830           abund
# 1    2.0   1.000000  0.396          acabal
# 2    3.0   1.000000  0.198           acall
# 3    4.0   1.000000  0.198            acat
# 4    5.0   1.000000  0.397          accion
# 5    6.0   1.000000  0.594           acept
# 6    7.0   1.000000  0.696      aceptacion
# 7    8.0   1.000000  0.429          acicat
# 8    9.0   1.000000  0.799      aclamacion
# 9   10.0   1.000000  0.799           aclam
# 10  11.0   1.000000  0.830        acogedor
# 11  12.0   1.000000  0.729            acog
# 12  13.0   1.000000  0.729          acomod
# 13  14.0   1.000000  0.264           acuci
# 14  15.0   1.000000  0.232           acuci
# 15  16.0   1.000000  0.331           adecu
# 16  17.0   1.000000  0.429           adict
# 17  18.0   1.000000  0.764           admir
# 18  19.0   1.000000  0.765           admir
# 19  20.0   1.000000  0.765      admiracion
# 20  21.0   1.000000  0.731           admir
# 21  22.0   1.000000  0.530           admit
# 22  23.0   1.000000  0.898            ador
# 23  24.0   1.000000  0.865            ador
# 24  25.0   1.000000  0.765       adoracion
# 25  26.0   1.000000  0.664            ador
# 26  27.0   1.000000  0.764            ador
# 27  28.0   1.000000  0.696           afabl
# 28  29.0   1.000000  0.764            afan
# 29  30.0   1.000000  0.864           afect
# ..   ...        ...    ...             ...
# 0    NaN   1.000000  1.000           cheee
# 0    NaN   1.500000  1.000             pas
# 0    NaN   1.000000  1.000          franel
# 0    NaN   1.000000  1.000         escaler
# 0    NaN   1.000000  1.000       joderrrrr
# 0    NaN   1.000000  1.000          enseri
# 0    NaN   2.000000  1.000         continu
# 0    NaN   2.000000  1.000         confisc
# 0    NaN   2.000000  1.000           elest
# 0    NaN   0.714286  1.000          critic
# 0    NaN   2.000000  1.000             ded
# 0    NaN  -1.000000  1.000         concept
# 0    NaN  -1.000000  1.000       reivindic
# 0    NaN  -1.000000  1.000        combatis
# 0    NaN  -1.000000  1.000         coloniz
# 0    NaN   0.765957  1.000             tid
# 0    NaN  -1.000000  1.000          client
# 0    NaN  -1.000000  1.000           pedaz
# 0    NaN   0.428571  1.000            norm
# 0    NaN   1.000000  1.000  constitucional
# 0    NaN  -1.000000  1.000    convencional
# 0    NaN   0.423729  1.000            idas
# 0    NaN   2.000000  1.000          precis
# 0    NaN   2.000000  1.000           separ
# 0    NaN  -1.000000  1.000           toler
# 0    NaN  -1.000000  1.000        promiscu
# 0    NaN   2.000000  1.000           enerv
# 0    NaN   1.285714  1.000           progr
# 0    NaN   2.000000  1.000           garit
# 0    NaN   2.000000  1.000            perr
#
# [11934 rows x 4 columns]

# %% [markdown]
# #### Elimnamos las palabras duplicadas que puedan estar en el diccionario

# %%
dict_label = dict_label.drop_duplicates(subset=['Palabra'])
dict_label
# Out:
#        #  Categoría    PFA        Palabra
# 0    1.0   1.000000  0.830          abund
# 1    2.0   1.000000  0.396         acabal
# 2    3.0   1.000000  0.198          acall
# 3    4.0   1.000000  0.198           acat
# 4    5.0   1.000000  0.397         accion
# 5    6.0   1.000000  0.594          acept
# 6    7.0   1.000000  0.696     aceptacion
# 7    8.0   1.000000  0.429         acicat
# 8    9.0   1.000000  0.799     aclamacion
# 9   10.0   1.000000  0.799          aclam
# 10  11.0   1.000000  0.830       acogedor
# 11  12.0   1.000000  0.729           acog
# 12  13.0   1.000000  0.729         acomod
# 13  14.0   1.000000  0.264          acuci
# 15  16.0   1.000000  0.331          adecu
# 16  17.0   1.000000  0.429          adict
# 17  18.0   1.000000  0.764          admir
# 19  20.0   1.000000  0.765     admiracion
# 21  22.0   1.000000  0.530          admit
# 22  23.0   1.000000  0.898           ador
# 24  25.0   1.000000  0.765      adoracion
# 27  28.0   1.000000  0.696          afabl
# 28  29.0   1.000000  0.764           afan
# 29  30.0   1.000000  0.864          afect
# 31  32.0   1.000000  0.966         afectu
# 34  35.0   1.000000  0.731      afervoriz
# 35  36.0   1.000000  0.729        aficion
# 37  38.0   1.000000  0.831        afortun
# 39  40.0   1.000000  0.899          agrad
# 41  42.0   1.000000  0.763        agradec
# ..   ...        ...    ...            ...
# 0    NaN   2.000000  1.000           sanm
# 0    NaN   2.000000  1.000       sarmient
# 0    NaN  -1.000000  1.000       habitual
# 0    NaN  -1.000000  1.000      subaltern
# 0    NaN  -1.000000  1.000            sil
# 0    NaN  -1.000000  1.000       pagarper
# 0    NaN  -1.000000  1.000       entender
# 0    NaN  -1.000000  1.000       pobreton
# 0    NaN  -1.000000  1.000  puestodevuelv
# 0    NaN   2.000000  1.000   gabrielsogli
# 0    NaN  -1.000000  1.000          cotiz
# 0    NaN   1.000000  1.000        meshast
# 0    NaN   1.000000  1.000           birr
# 0    NaN   1.000000  1.000        comprat
# 0    NaN  -0.714286  1.000           celu
# 0    NaN   1.000000  1.000       contrubu
# 0    NaN   1.000000  1.000          cheee
# 0    NaN   1.000000  1.000         franel
# 0    NaN   1.000000  1.000        escaler
# 0    NaN   1.000000  1.000      joderrrrr
# 0    NaN   1.000000  1.000         enseri
# 0    NaN   2.000000  1.000          elest
# 0    NaN  -1.000000  1.000        concept
# 0    NaN  -1.000000  1.000       combatis
# 0    NaN   0.765957  1.000            tid
# 0    NaN  -1.000000  1.000   convencional
# 0    NaN   0.423729  1.000           idas
# 0    NaN  -1.000000  1.000       promiscu
# 0    NaN   2.000000  1.000          enerv
# 0    NaN   2.000000  1.000          garit
#
# [7277 rows x 4 columns]

# %% [markdown]
# #### Esta función determina la polaridad de un tweet en funcion del diccionario

# %%
def analisis_sentimiento(text):
    tienePalabra = False
    valor = 999999
    filtered_words = [word for word in text.split() if word not in stopwords.words('spanish')]
    for word in filtered_words:
        if dict_label.loc[dict_label['Palabra'].isin([stemmer.stem(word)])]['Categoría'].any(): 
            if not tienePalabra:
                tienePalabra = True
                valor = 0
            try:                
                valor = valor + float(dict_label.loc[dict_label['Palabra'].isin([stemmer.stem(word)])]['Categoría'])
            except Exception as e: 
                print(e)
                print(dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'])               
    
    return valor

# %% [markdown]
# #### Se calcula la polaridad del conjunto de tweets de test

# %%
correcto = 0
max = 0
min = 0
ref = []
testVal= []

if(clasificacion == 2):
    #BINARIO
    for id, tweet in test.iterrows(): 
        sentimiento = analisis_sentimiento(str(tweet.text))
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento  
            ref.append(1 if int(tweet.sentiment) == 1 else -1)      
            if(sentimiento <= -1): 
                testVal.append(-1)
            else:
                testVal.append(1)
        
else:
    #TERNARIO
    for id, tweet in test.iterrows():    
        sentimiento = analisis_sentimiento(str(tweet.text))
        if (int(tweet.sentiment) == 0):
            valor_tweet = -1
        else: 
            valor_tweet = int(tweet.sentiment)
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento
            ref.append(valor_tweet)  
            if sentimiento > 3 and sentimiento < 7:
                testVal.append(2)
            elif(sentimiento <= 4): 
                testVal.append(-1)
            else:
                testVal.append(1)

# %% [markdown]
# #### Guardamos los resultados de la clasificación.

# %%
file1 = open(filename2 + '.txt',"w") 

accuracyDict = {}
  
# \n is placed to indicate EOL (End of Line) 
file1.write("Resultados "+ filename2 + ' \n\n') 

writer = pd.ExcelWriter(path+directory+'clasification_report_'+file_2+'_STEMMING.xlsx', engine='xlsxwriter')
writerCM = pd.ExcelWriter(path+directory+'confusion_matrix_'+file_2+'_STEMMING.xlsx', engine='xlsxwriter')

#     print("***** METRICAS CLASIFICADOR "+nombre+" *****")
file1.write("***** METRICAS DICCIONARIO: SEL *****\n\n") 
#     print("Exactitud (accuracy) " +  str(accuracy(ref, test)*100))
file1.write("Exactitud (accuracy) " +  str(accuracy(ref, testVal)*100)+"\n") 
reference_set = set(ref)
test_set = set(testVal)
#     print("Precision " +str(precision(reference_set, test_set)))
file1.write("Precision " +str(precision(reference_set, test_set))+"\n")
#     print("Recall " +str(recall(reference_set, test_set)))
file1.write("Recall " +str(recall(reference_set, test_set))+"\n")
#     print("F measure " + str(f_measure(reference_set, test_set)))
file1.write("F measure " + str(f_measure(reference_set, test_set))+"\n\n")
file1.write("Matriz de confusión \n")
#     print(ConfusionMatrix(ref, test))   
file1.write(str(ConfusionMatrix(ref, testVal)))
file1.write('\n')
file1.write("Reporte de clasificación\n")
#     print(metrics.classification_report(ref,test,digits=3))
file1.write(metrics.classification_report(ref,testVal,digits=3)+'\n')
    
    
    
data = {'y_Predicted': testVal,
    'y_Actual':   ref
    }

df_cm = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
confusion_matrix = pd.crosstab(df_cm['y_Actual'], df_cm['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

confusion_matrix.to_excel(writerCM,sheet_name=nombre) 

report = metrics.classification_report(ref, testVal, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_excel(writer,sheet_name=nombre)


file1.write("****************************************\n\n\n\n")

accuracyDict[nombre] = str(accuracy(ref, testVal)*100)

df_ac = pd.DataFrame([accuracyDict])   
df_ac = df_ac.T
df_ac.to_excel(path+directory+'accuracy_'+file_1+'_STEMMING.xlsx')

file1.close() #to change file access modes 
writer.save()
