# %%
import pandas as pd
import re
import string
from nltk.corpus import stopwords
import numpy as np
from nltk.metrics import *
from sklearn import metrics
from os import scandir, getcwd
import json


import warnings
warnings.filterwarnings("ignore")

# %%
diccionario = "senti_strength.xlsx"
tweets = 'tweets_preprocessed.xlsx'
path = files_path=getcwd()
file_1 = "SentiStrength_1"
file_2 = "SentiStrength_2"
# directory = '\\BINARIO\\'
directory = '\\TERNARIO\\'


filename_1 = path+directory+file_1
filename_2 = path+directory+file_2
nombre = 'SentiStrength'

clasificacion = 3

# %%
df = pd.read_excel(diccionario)
df
# Out:
#              Palabra  Categoría
# 0         abandonado         -4
# 1             abejas         -2
# 2            ability          1
# 3             aborto         -3
# 4          abrasador         -3
# 5             abrazo          4
# 6               abre          1
# 7              abren          1
# 8           abrumado         -3
# 9            absurdo         -2
# 10        abundancia          2
# 11            aburre         -2
# 12          aburrido         -3
# 13              abus         -4
# 14             abusi         -4
# 15              acab         -1
# 16             acaso         -1
# 17         accidente         -4
# 18         acercarte          1
# 19             acido         -2
# 20             ácido         -2
# 21             aclar          2
# 22          acogedor          3
# 23    acontecimiento          1
# 24              acre          1
# 25             activ          2
# 26         activismo          1
# 27           acuerdo          3
# 28       acurrucarse          2
# 29            adicto         -3
# ...              ...        ...
# 1379           verde          2
# 1380      vergonzoso         -2
# 1381       verguenza         -3
# 1382       vertedero         -3
# 1383         vestido          2
# 1384          viajes          3
# 1385         víctima         -4
# 1386      victimismo         -3
# 1387        victoria          3
# 1388            vida          4
# 1389          vidrio          1
# 1390       vigilante          1
# 1391        vigoroso          1
# 1392            vino          1
# 1393       violación         -4
# 1394        violento         -4
# 1395          violin          2
# 1396          violín          2
# 1397          virgen          1
# 1398          virtud          3
# 1399         viruela         -4
# 1400          visión          2
# 1401          vívido          1
# 1402            vivo          4
# 1403          volcán         -2
# 1404          vomito         -4
# 1405          vómito         -4
# 1406            yate          2
# 1407          zafiro          2
# 1408           zurra         -4
#
# [1406 rows x 2 columns]

# %%
dict_part = df

# %%
dict_label=dict_part
dict_label
# Out:
#              Palabra  Categoría
# 0         abandonado         -4
# 1             abejas         -2
# 2            ability          1
# 3             aborto         -3
# 4          abrasador         -3
# 5             abrazo          4
# 6               abre          1
# 7              abren          1
# 8           abrumado         -3
# 9            absurdo         -2
# 10        abundancia          2
# 11            aburre         -2
# 12          aburrido         -3
# 13              abus         -4
# 14             abusi         -4
# 15              acab         -1
# 16             acaso         -1
# 17         accidente         -4
# 18         acercarte          1
# 19             acido         -2
# 20             ácido         -2
# 21             aclar          2
# 22          acogedor          3
# 23    acontecimiento          1
# 24              acre          1
# 25             activ          2
# 26         activismo          1
# 27           acuerdo          3
# 28       acurrucarse          2
# 29            adicto         -3
# ...              ...        ...
# 1379           verde          2
# 1380      vergonzoso         -2
# 1381       verguenza         -3
# 1382       vertedero         -3
# 1383         vestido          2
# 1384          viajes          3
# 1385         víctima         -4
# 1386      victimismo         -3
# 1387        victoria          3
# 1388            vida          4
# 1389          vidrio          1
# 1390       vigilante          1
# 1391        vigoroso          1
# 1392            vino          1
# 1393       violación         -4
# 1394        violento         -4
# 1395          violin          2
# 1396          violín          2
# 1397          virgen          1
# 1398          virtud          3
# 1399         viruela         -4
# 1400          visión          2
# 1401          vívido          1
# 1402            vivo          4
# 1403          volcán         -2
# 1404          vomito         -4
# 1405          vómito         -4
# 1406            yate          2
# 1407          zafiro          2
# 1408           zurra         -4
#
# [1406 rows x 2 columns]

# %%
def preprocesamiento_dict(row):
    a,b = 'áéíóúü','aeiouu'
    trans = str.maketrans(a,b)
    replaced_links = row["Palabra"].translate(trans)  
    
    return replaced_links

# %%
dict_label["Palabra"] = dict_label.apply(preprocesamiento_dict, axis=1)
dict_label = dict_label.drop_duplicates(subset=['Palabra'])
dict_label = dict_label.reset_index()
dict_label
# Out:
#       index         Palabra  Categoría
# 0         0      abandonado         -4
# 1         1          abejas         -2
# 2         2         ability          1
# 3         3          aborto         -3
# 4         4       abrasador         -3
# 5         5          abrazo          4
# 6         6            abre          1
# 7         7           abren          1
# 8         8        abrumado         -3
# 9         9         absurdo         -2
# 10       10      abundancia          2
# 11       11          aburre         -2
# 12       12        aburrido         -3
# 13       13            abus         -4
# 14       14           abusi         -4
# 15       15            acab         -1
# 16       16           acaso         -1
# 17       17       accidente         -4
# 18       18       acercarte          1
# 19       19           acido         -2
# 20       21           aclar          2
# 21       22        acogedor          3
# 22       23  acontecimiento          1
# 23       24            acre          1
# 24       25           activ          2
# 25       26       activismo          1
# 26       27         acuerdo          3
# 27       28     acurrucarse          2
# 28       29          adicto         -3
# 29       30       adinerado          2
# ...     ...             ...        ...
# 1253   1377         ventana          1
# 1254   1378          verdad          3
# 1255   1379           verde          2
# 1256   1380      vergonzoso         -2
# 1257   1381       verguenza         -3
# 1258   1382       vertedero         -3
# 1259   1383         vestido          2
# 1260   1384          viajes          3
# 1261   1385         victima         -4
# 1262   1386      victimismo         -3
# 1263   1387        victoria          3
# 1264   1388            vida          4
# 1265   1389          vidrio          1
# 1266   1390       vigilante          1
# 1267   1391        vigoroso          1
# 1268   1392            vino          1
# 1269   1393       violacion         -4
# 1270   1394        violento         -4
# 1271   1395          violin          2
# 1272   1397          virgen          1
# 1273   1398          virtud          3
# 1274   1399         viruela         -4
# 1275   1400          vision          2
# 1276   1401          vivido          1
# 1277   1402            vivo          4
# 1278   1403          volcan         -2
# 1279   1404          vomito         -4
# 1280   1406            yate          2
# 1281   1407          zafiro          2
# 1282   1408           zurra         -4
#
# [1283 rows x 3 columns]

# %% [markdown]
# ### LEO LOS TWEETS

# %%
df = pd.read_excel(tweets)

# %%
df_label = df[df.sentiment < clasificacion]
df_clean = df_label

# %% [markdown]
# # dividir en prueba y entrenamiento

# %%
train=df_clean.sample(frac=0.8,random_state=200)
test=df_clean.drop(train.index)

train = train[train.sentiment < clasificacion]

df_clean = train

# %%
df_clean = df_clean.dropna()

# %%
dict_label = dict_label.drop_duplicates(subset=['Palabra'])
dict_label["Palabra"] = dict_label.apply(preprocesamiento_dict, axis=1)
dict_label
# Out:
#       index         Palabra  Categoría
# 0         0      abandonado         -4
# 1         1          abejas         -2
# 2         2         ability          1
# 3         3          aborto         -3
# 4         4       abrasador         -3
# 5         5          abrazo          4
# 6         6            abre          1
# 7         7           abren          1
# 8         8        abrumado         -3
# 9         9         absurdo         -2
# 10       10      abundancia          2
# 11       11          aburre         -2
# 12       12        aburrido         -3
# 13       13            abus         -4
# 14       14           abusi         -4
# 15       15            acab         -1
# 16       16           acaso         -1
# 17       17       accidente         -4
# 18       18       acercarte          1
# 19       19           acido         -2
# 20       21           aclar          2
# 21       22        acogedor          3
# 22       23  acontecimiento          1
# 23       24            acre          1
# 24       25           activ          2
# 25       26       activismo          1
# 26       27         acuerdo          3
# 27       28     acurrucarse          2
# 28       29          adicto         -3
# 29       30       adinerado          2
# ...     ...             ...        ...
# 1253   1377         ventana          1
# 1254   1378          verdad          3
# 1255   1379           verde          2
# 1256   1380      vergonzoso         -2
# 1257   1381       verguenza         -3
# 1258   1382       vertedero         -3
# 1259   1383         vestido          2
# 1260   1384          viajes          3
# 1261   1385         victima         -4
# 1262   1386      victimismo         -3
# 1263   1387        victoria          3
# 1264   1388            vida          4
# 1265   1389          vidrio          1
# 1266   1390       vigilante          1
# 1267   1391        vigoroso          1
# 1268   1392            vino          1
# 1269   1393       violacion         -4
# 1270   1394        violento         -4
# 1271   1395          violin          2
# 1272   1397          virgen          1
# 1273   1398          virtud          3
# 1274   1399         viruela         -4
# 1275   1400          vision          2
# 1276   1401          vivido          1
# 1277   1402            vivo          4
# 1278   1403          volcan         -2
# 1279   1404          vomito         -4
# 1280   1406            yate          2
# 1281   1407          zafiro          2
# 1282   1408           zurra         -4
#
# [1283 rows x 3 columns]

# %%
dict_label_stem = dict_label

# %%
dict_label = dict_label.reset_index()

# %%
dict_label = dict_label.dropna()
# Out:
#       level_0  index         Palabra  Categoría
# 0           0      0      abandonado         -4
# 1           1      1          abejas         -2
# 2           2      2         ability          1
# 3           3      3          aborto         -3
# 4           4      4       abrasador         -3
# 5           5      5          abrazo          4
# 6           6      6            abre          1
# 7           7      7           abren          1
# 8           8      8        abrumado         -3
# 9           9      9         absurdo         -2
# 10         10     10      abundancia          2
# 11         11     11          aburre         -2
# 12         12     12        aburrido         -3
# 13         13     13            abus         -4
# 14         14     14           abusi         -4
# 15         15     15            acab         -1
# 16         16     16           acaso         -1
# 17         17     17       accidente         -4
# 18         18     18       acercarte          1
# 19         19     19           acido         -2
# 20         20     21           aclar          2
# 21         21     22        acogedor          3
# 22         22     23  acontecimiento          1
# 23         23     24            acre          1
# 24         24     25           activ          2
# 25         25     26       activismo          1
# 26         26     27         acuerdo          3
# 27         27     28     acurrucarse          2
# 28         28     29          adicto         -3
# 29         29     30       adinerado          2
# ...       ...    ...             ...        ...
# 1253     1253   1377         ventana          1
# 1254     1254   1378          verdad          3
# 1255     1255   1379           verde          2
# 1256     1256   1380      vergonzoso         -2
# 1257     1257   1381       verguenza         -3
# 1258     1258   1382       vertedero         -3
# 1259     1259   1383         vestido          2
# 1260     1260   1384          viajes          3
# 1261     1261   1385         victima         -4
# 1262     1262   1386      victimismo         -3
# 1263     1263   1387        victoria          3
# 1264     1264   1388            vida          4
# 1265     1265   1389          vidrio          1
# 1266     1266   1390       vigilante          1
# 1267     1267   1391        vigoroso          1
# 1268     1268   1392            vino          1
# 1269     1269   1393       violacion         -4
# 1270     1270   1394        violento         -4
# 1271     1271   1395          violin          2
# 1272     1272   1397          virgen          1
# 1273     1273   1398          virtud          3
# 1274     1274   1399         viruela         -4
# 1275     1275   1400          vision          2
# 1276     1276   1401          vivido          1
# 1277     1277   1402            vivo          4
# 1278     1278   1403          volcan         -2
# 1279     1279   1404          vomito         -4
# 1280     1280   1406            yate          2
# 1281     1281   1407          zafiro          2
# 1282     1282   1408           zurra         -4
#
# [1283 rows x 4 columns]

# %%
def polaridadPromedio(palabra):
    tweetsQueTienenPalabra = df_clean[df_clean['text'].str.contains(palabra)]
    #print(tweetsQueTienenPalabra)
    avg = tweetsQueTienenPalabra["sentiment"].mean()
    return avg

# %%
df_aux = df_clean

for id, tweet in df_aux.iterrows():
    filtered_words = [word for word in tweet.text.split() if word not in stopwords.words('spanish')]
    for word in filtered_words:
        if dict_label.loc[dict_label['Palabra'].isin([word])]['Palabra'].any():
            a=1
        else:        
            avg = polaridadPromedio(str(word))
            df2 = pd.DataFrame([[word,avg]], columns=['Palabra','Categoría'])
            dict_label = dict_label.append(df2)

# %% [markdown]
# # probar modelo

# %%
def analisis_sentimiento(text):
    tienePalabra = False
    valor = 999999
    filtered_words = [word for word in text.split() if word not in stopwords.words('spanish')]
    for word in filtered_words:
        if dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'].any(): 
            if not tienePalabra:
                tienePalabra = True
                valor = 0
            try:                
                valor = valor + float(dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'])
            except Exception as e: 
                print(e)
                print(dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'])               
    
    return valor

# %%
correcto = 0
max = 0
min = 0
ref = []
testVal= []

if(clasificacion == 2):
    #BINARIO
    for id, tweet in test.iterrows(): 
        sentimiento = analisis_sentimiento(str(tweet.text))
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento  
            ref.append(1 if int(tweet.sentiment) == 1 else -1)      
            if(sentimiento <= 1.5): 
                testVal.append(-1)
            else:
                testVal.append(1)
        
else:
    #TERNARIO
    for id, tweet in test.iterrows():    
        sentimiento = analisis_sentimiento(str(tweet.text))
        if (int(tweet.sentiment) == 0):
            valor_tweet = -1
        else: 
            valor_tweet = int(tweet.sentiment)
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento
            ref.append(valor_tweet)  
            if sentimiento > 8 and sentimiento < 16:
                testVal.append(2)
            elif(sentimiento <= 8): 
                testVal.append(-1)
            else:
                testVal.append(1)

# %%
file1 = open(filename_1 + '.txt',"w") 

accuracyDict = {}
  
# \n is placed to indicate EOL (End of Line) 
file1.write("Resultados "+ filename_1 + ' \n\n') 

writer = pd.ExcelWriter(path+directory+'clasification_report_'+file_1+'.xlsx', engine='xlsxwriter')
writerCM = pd.ExcelWriter(path+directory+'confusion_matrix_'+file_1+'.xlsx', engine='xlsxwriter')

#     print("***** METRICAS CLASIFICADOR "+nombre+" *****")
file1.write("***** METRICAS DICCIONARIO: SentiStrength *****\n\n") 
#     print("Exactitud (accuracy) " +  str(accuracy(ref, test)*100))
file1.write("Exactitud (accuracy) " +  str(accuracy(ref, testVal)*100)+"\n") 
reference_set = set(ref)
test_set = set(testVal)
#     print("Precision " +str(precision(reference_set, test_set)))
file1.write("Precision " +str(precision(reference_set, test_set))+"\n")
#     print("Recall " +str(recall(reference_set, test_set)))
file1.write("Recall " +str(recall(reference_set, test_set))+"\n")
#     print("F measure " + str(f_measure(reference_set, test_set)))
file1.write("F measure " + str(f_measure(reference_set, test_set))+"\n\n")
file1.write("Matriz de confusión \n")
#     print(ConfusionMatrix(ref, test))   
file1.write(str(ConfusionMatrix(ref, testVal)))
file1.write('\n')
file1.write("Reporte de clasificación\n")
#     print(metrics.classification_report(ref,test,digits=3))
file1.write(metrics.classification_report(ref,testVal,digits=3)+'\n')
    
    
    
data = {'y_Predicted': testVal,
    'y_Actual':   ref
    }

df_cm = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
confusion_matrix = pd.crosstab(df_cm['y_Actual'], df_cm['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

confusion_matrix.to_excel(writerCM,sheet_name=nombre) 

report = metrics.classification_report(ref, testVal, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_excel(writer,sheet_name=nombre)


file1.write("****************************************\n\n\n\n")

accuracyDict[nombre] = str(accuracy(ref, testVal)*100)

df_ac = pd.DataFrame([accuracyDict])   
df_ac = df_ac.T
df_ac.to_excel(path+directory+'accuracy_'+file_1+'.xlsx')

file1.close() #to change file access modes 
writer.save()

# %% [markdown]
# # stemmer

# %%
from nltk.stem import SnowballStemmer
stemmer = SnowballStemmer('spanish')

# %%
def lematizacion(row):
    result = stemmer.stem(row['Palabra'])
    return result

# %%
dict_label= dict_label_stem
dict_label['Palabra'] = dict_label.apply(lematizacion, axis=1)
dict_label
# Out:
#       index    Palabra  Categoría
# 0         0    abandon         -4
# 1         1       abej         -2
# 2         2    ability          1
# 3         3      abort         -3
# 4         4      abras         -3
# 5         5      abraz          4
# 6         6       abre          1
# 7         7      abren          1
# 8         8      abrum         -3
# 9         9     absurd         -2
# 10       10      abund          2
# 11       11      aburr         -2
# 12       12      aburr         -3
# 13       13       abus         -4
# 14       14      abusi         -4
# 15       15       acab         -1
# 16       16       acas         -1
# 17       17   accident         -4
# 18       18   acercart          1
# 19       19       acid         -2
# 20       21      aclar          2
# 21       22   acogedor          3
# 22       23    acontec          1
# 23       24       acre          1
# 24       25      activ          2
# 25       26      activ          1
# 26       27     acuerd          3
# 27       28    acurruc          2
# 28       29      adict         -3
# 29       30     adiner          2
# ...     ...        ...        ...
# 1253   1377     ventan          1
# 1254   1378       verd          3
# 1255   1379       verd          2
# 1256   1380    vergonz         -2
# 1257   1381   verguenz         -3
# 1258   1382   verteder         -3
# 1259   1383       vest          2
# 1260   1384       viaj          3
# 1261   1385     victim         -4
# 1262   1386     victim         -3
# 1263   1387    victori          3
# 1264   1388        vid          4
# 1265   1389      vidri          1
# 1266   1390      vigil          1
# 1267   1391      vigor          1
# 1268   1392        vin          1
# 1269   1393  violacion         -4
# 1270   1394    violent         -4
# 1271   1395     violin          2
# 1272   1397       virg          1
# 1273   1398     virtud          3
# 1274   1399     viruel         -4
# 1275   1400     vision          2
# 1276   1401        viv          1
# 1277   1402        viv          4
# 1278   1403       volc         -2
# 1279   1404      vomit         -4
# 1280   1406        yat          2
# 1281   1407      zafir          2
# 1282   1408       zurr         -4
#
# [1283 rows x 3 columns]

# %%
dict_label = dict_label.drop_duplicates(subset=['Palabra'])
dict_label
# Out:
#       index    Palabra  Categoría
# 0         0    abandon         -4
# 1         1       abej         -2
# 2         2    ability          1
# 3         3      abort         -3
# 4         4      abras         -3
# 5         5      abraz          4
# 6         6       abre          1
# 7         7      abren          1
# 8         8      abrum         -3
# 9         9     absurd         -2
# 10       10      abund          2
# 11       11      aburr         -2
# 13       13       abus         -4
# 14       14      abusi         -4
# 15       15       acab         -1
# 16       16       acas         -1
# 17       17   accident         -4
# 18       18   acercart          1
# 19       19       acid         -2
# 20       21      aclar          2
# 21       22   acogedor          3
# 22       23    acontec          1
# 23       24       acre          1
# 24       25      activ          2
# 26       27     acuerd          3
# 27       28    acurruc          2
# 28       29      adict         -3
# 29       30     adiner          2
# 30       31        adi         -2
# 31       32      admir          3
# ...     ...        ...        ...
# 1250   1374       vend          1
# 1251   1375      venen         -3
# 1252   1376     ventaj          2
# 1253   1377     ventan          1
# 1254   1378       verd          3
# 1256   1380    vergonz         -2
# 1257   1381   verguenz         -3
# 1258   1382   verteder         -3
# 1259   1383       vest          2
# 1260   1384       viaj          3
# 1261   1385     victim         -4
# 1263   1387    victori          3
# 1264   1388        vid          4
# 1265   1389      vidri          1
# 1266   1390      vigil          1
# 1267   1391      vigor          1
# 1268   1392        vin          1
# 1269   1393  violacion         -4
# 1270   1394    violent         -4
# 1271   1395     violin          2
# 1272   1397       virg          1
# 1273   1398     virtud          3
# 1274   1399     viruel         -4
# 1275   1400     vision          2
# 1276   1401        viv          1
# 1278   1403       volc         -2
# 1279   1404      vomit         -4
# 1280   1406        yat          2
# 1281   1407      zafir          2
# 1282   1408       zurr         -4
#
# [1192 rows x 3 columns]

# %%
#CON STEMMING
def analisis_sentimiento(text):
    tienePalabra = False
    valor = 999999
    filtered_words = [word for word in text.split() if word not in stopwords.words('spanish')]
    for word in filtered_words:
        if dict_label.loc[dict_label['Palabra'].isin([stemmer.stem(word)])]['Categoría'].any(): 
            if not tienePalabra:
                tienePalabra = True
                valor = 0
            try:                
                valor = valor + float(dict_label.loc[dict_label['Palabra'].isin([stemmer.stem(word)])]['Categoría'])
            except Exception as e: 
                print(e)
                print(dict_label.loc[dict_label['Palabra'].isin([word])]['Categoría'])               
    
    return valor

# %%
correcto = 0
max = 0
min = 0
ref = []
testVal= []

if(clasificacion == 2):
    #BINARIO
    for id, tweet in test.iterrows(): 
        sentimiento = analisis_sentimiento(str(tweet.text))
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento  
            ref.append(1 if int(tweet.sentiment) == 1 else -1)      
            if(sentimiento <= 1.5): 
                testVal.append(-1)
            else:
                testVal.append(1)
        
else:
    #TERNARIO
    for id, tweet in test.iterrows():    
        sentimiento = analisis_sentimiento(str(tweet.text))
        if (int(tweet.sentiment) == 0):
            valor_tweet = -1
        else: 
            valor_tweet = int(tweet.sentiment)
        if(sentimiento != 999999):
            if(sentimiento > max):
                max = sentimiento
            if(sentimiento < min):
                min = sentimiento
            ref.append(valor_tweet)  
            if sentimiento > 8 and sentimiento < 16:
                testVal.append(2)
            elif(sentimiento <= 8): 
                testVal.append(-1)
            else:
                testVal.append(1)

# %%
file1 = open(filename_2 + '.txt',"w") 

accuracyDict = {}
  
# \n is placed to indicate EOL (End of Line) 
file1.write("Resultados "+ filename_2 + ' \n\n') 

writer = pd.ExcelWriter(path+directory+'clasification_report_'+file_2+'_STEMMING.xlsx', engine='xlsxwriter')
writerCM = pd.ExcelWriter(path+directory+'confusion_matrix_'+file_2+'_STEMMING.xlsx', engine='xlsxwriter')

#     print("***** METRICAS CLASIFICADOR "+nombre+" *****")
file1.write("***** METRICAS DICCIONARIO: SentiStrength *****\n\n") 
#     print("Exactitud (accuracy) " +  str(accuracy(ref, test)*100))
file1.write("Exactitud (accuracy) " +  str(accuracy(ref, testVal)*100)+"\n") 
reference_set = set(ref)
test_set = set(testVal)
#     print("Precision " +str(precision(reference_set, test_set)))
file1.write("Precision " +str(precision(reference_set, test_set))+"\n")
#     print("Recall " +str(recall(reference_set, test_set)))
file1.write("Recall " +str(recall(reference_set, test_set))+"\n")
#     print("F measure " + str(f_measure(reference_set, test_set)))
file1.write("F measure " + str(f_measure(reference_set, test_set))+"\n\n")
file1.write("Matriz de confusión \n")
#     print(ConfusionMatrix(ref, test))   
file1.write(str(ConfusionMatrix(ref, testVal)))
file1.write('\n')
file1.write("Reporte de clasificación\n")
#     print(metrics.classification_report(ref,test,digits=3))
file1.write(metrics.classification_report(ref,testVal,digits=3)+'\n')
    
    
    
data = {'y_Predicted': testVal,
    'y_Actual':   ref
    }

df_cm = pd.DataFrame(data, columns=['y_Actual','y_Predicted'])
confusion_matrix = pd.crosstab(df_cm['y_Actual'], df_cm['y_Predicted'], rownames=['Actual'], colnames=['Predicted'])

confusion_matrix.to_excel(writerCM,sheet_name=nombre) 

report = metrics.classification_report(ref, testVal, output_dict=True)
df = pd.DataFrame(report).transpose()
df.to_excel(writer,sheet_name=nombre)


file1.write("****************************************\n\n\n\n")

accuracyDict[nombre] = str(accuracy(ref, testVal)*100)

df_ac = pd.DataFrame([accuracyDict])   
df_ac = df_ac.T
df_ac.to_excel(path+directory+'accuracy_'+file_2+'_STEMMING.xlsx')

file1.close() #to change file access modes 
writer.save()
